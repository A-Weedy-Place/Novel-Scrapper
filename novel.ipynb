# %%
import requests
from bs4 import BeautifulSoup
import re

def scrape_chapter(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Extracting the chapter title
    title_tag = soup.find('h1')
    if title_tag:
        title = title_tag.text.strip()
    else:
        title = "No Title Found"

    # Extracting the main content of the chapter
    content_div = soup.find('div', class_='entry-content')  # Use the correct class or ID for the main content
    if content_div:
        paragraphs = content_div.find_all('p')
        chapter_text = '\n'.join(p.text.strip() for p in paragraphs)
    else:
        chapter_text = "No Content Found"

    # Return the extracted title and chapter content
    return title, chapter_text

def sanitize_file_name(file_name):
    # Replace invalid characters with an underscore or remove them
    file_name = re.sub(r'[\\/*?:"<>|]', '_', file_name)
    file_name = re.sub(r'[’]', '', file_name)  # Remove the apostrophe character
    return file_name

# File to save all chapters
output_file_name = "Sorcerers_Handbook_All_Chapters.txt"

# Loop through all chapter URLs
base_url = 'https://hoxionia.com/sorcerers-handbook-chapter-'
total_chapters = 352

with open(output_file_name, 'w', encoding='utf-8') as output_file:
    for i in range(1, total_chapters + 1):
        chapter_url = f"{base_url}{i}/"
        title, chapter_text = scrape_chapter(chapter_url)
        
        # Write the title and content to the file
        output_file.write(f"Title: {title}\n\n")
        output_file.write(chapter_text)
        output_file.write("\n\n" + "="*50 + "\n\n")  # Add some space between chapters

        print(f"Chapter {i} scraped and added to the file.")

print(f"All {total_chapters} chapters have been scraped and saved to {output_file_name}.")
# Out:
# Chapter 1 scraped and added to the file.
# Chapter 2 scraped and added to the file.
# Chapter 3 scraped and added to the file.
# Chapter 4 scraped and added to the file.
# Chapter 5 scraped and added to the file.
# Chapter 6 scraped and added to the file.
# Chapter 7 scraped and added to the file.
# Chapter 8 scraped and added to the file.
# Chapter 9 scraped and added to the file.
# Chapter 10 scraped and added to the file.
# Chapter 11 scraped and added to the file.
# Chapter 12 scraped and added to the file.
# Chapter 13 scraped and added to the file.
# Chapter 14 scraped and added to the file.
# Chapter 15 scraped and added to the file.
# Chapter 16 scraped and added to the file.
# Chapter 17 scraped and added to the file.
# Chapter 18 scraped and added to the file.
# Chapter 19 scraped and added to the file.
# Chapter 20 scraped and added to the file.
# Chapter 21 scraped and added to the file.
# Chapter 22 scraped and added to the file.
# Chapter 23 scraped and added to the file.
# Chapter 24 scraped and added to the file.
# Chapter 25 scraped and added to the file.
# Chapter 26 scraped and added to the file.
# Chapter 27 scraped and added to the file.
# Chapter 28 scraped and added to the file.
# Chapter 29 scraped and added to the file.
# Chapter 30 scraped and added to the file.
# Chapter 31 scraped and added to the file.
# Chapter 32 scraped and added to the file.
# Chapter 33 scraped and added to the file.
# Chapter 34 scraped and added to the file.
# Chapter 35 scraped and added to the file.
# Chapter 36 scraped and added to the file.
# Chapter 37 scraped and added to the file.
# Chapter 38 scraped and added to the file.
# Chapter 39 scraped and added to the file.
# Chapter 40 scraped and added to the file.
# Chapter 41 scraped and added to the file.
# Chapter 42 scraped and added to the file.
# Chapter 43 scraped and added to the file.
# Chapter 44 scraped and added to the file.
# Chapter 45 scraped and added to the file.
# Chapter 46 scraped and added to the file.
# Chapter 47 scraped and added to the file.
# Chapter 48 scraped and added to the file.
# Chapter 49 scraped and added to the file.
# Chapter 50 scraped and added to the file.
# Chapter 51 scraped and added to the file.
# Chapter 52 scraped and added to the file.
# Chapter 53 scraped and added to the file.
# Chapter 54 scraped and added to the file.
# Chapter 55 scraped and added to the file.
# Chapter 56 scraped and added to the file.
# Chapter 57 scraped and added to the file.
# Chapter 58 scraped and added to the file.
# Chapter 59 scraped and added to the file.
# Chapter 60 scraped and added to the file.
# Chapter 61 scraped and added to the file.
# Chapter 62 scraped and added to the file.
# Chapter 63 scraped and added to the file.
# Chapter 64 scraped and added to the file.
# Chapter 65 scraped and added to the file.
# Chapter 66 scraped and added to the file.
# Chapter 67 scraped and added to the file.
# Chapter 68 scraped and added to the file.
# Chapter 69 scraped and added to the file.
# Chapter 70 scraped and added to the file.
# Chapter 71 scraped and added to the file.
# Chapter 72 scraped and added to the file.
# Chapter 73 scraped and added to the file.
# Chapter 74 scraped and added to the file.
# Chapter 75 scraped and added to the file.
# Chapter 76 scraped and added to the file.
# Chapter 77 scraped and added to the file.
# Chapter 78 scraped and added to the file.
# Chapter 79 scraped and added to the file.
# Chapter 80 scraped and added to the file.
# Chapter 81 scraped and added to the file.
# Chapter 82 scraped and added to the file.
# Chapter 83 scraped and added to the file.
# Chapter 84 scraped and added to the file.
# Chapter 85 scraped and added to the file.
# Chapter 86 scraped and added to the file.
# Chapter 87 scraped and added to the file.
# Chapter 88 scraped and added to the file.
# Chapter 89 scraped and added to the file.
# Chapter 90 scraped and added to the file.
# Chapter 91 scraped and added to the file.
# Chapter 92 scraped and added to the file.
# Chapter 93 scraped and added to the file.
# Chapter 94 scraped and added to the file.
# Chapter 95 scraped and added to the file.
# Chapter 96 scraped and added to the file.
# Chapter 97 scraped and added to the file.
# Chapter 98 scraped and added to the file.
# Chapter 99 scraped and added to the file.
# Chapter 100 scraped and added to the file.
# Chapter 101 scraped and added to the file.
# Chapter 102 scraped and added to the file.
# Chapter 103 scraped and added to the file.
# Chapter 104 scraped and added to the file.
# Chapter 105 scraped and added to the file.
# Chapter 106 scraped and added to the file.
# Chapter 107 scraped and added to the file.
# Chapter 108 scraped and added to the file.
# Chapter 109 scraped and added to the file.
# Chapter 110 scraped and added to the file.
# Chapter 111 scraped and added to the file.
# Chapter 112 scraped and added to the file.
# Chapter 113 scraped and added to the file.
# Chapter 114 scraped and added to the file.
# Chapter 115 scraped and added to the file.
# Chapter 116 scraped and added to the file.
# Chapter 117 scraped and added to the file.
# Chapter 118 scraped and added to the file.
# Chapter 119 scraped and added to the file.
# Chapter 120 scraped and added to the file.
# Chapter 121 scraped and added to the file.
# Chapter 122 scraped and added to the file.
# Chapter 123 scraped and added to the file.
# Chapter 124 scraped and added to the file.
# Chapter 125 scraped and added to the file.
# Chapter 126 scraped and added to the file.
# Chapter 127 scraped and added to the file.
# Chapter 128 scraped and added to the file.
# Chapter 129 scraped and added to the file.
# Chapter 130 scraped and added to the file.
# Chapter 131 scraped and added to the file.
# Chapter 132 scraped and added to the file.
# Chapter 133 scraped and added to the file.
# Chapter 134 scraped and added to the file.
# Chapter 135 scraped and added to the file.
# Chapter 136 scraped and added to the file.
# Chapter 137 scraped and added to the file.
# Chapter 138 scraped and added to the file.
# Chapter 139 scraped and added to the file.
# Chapter 140 scraped and added to the file.
# Chapter 141 scraped and added to the file.
# Chapter 142 scraped and added to the file.
# Chapter 143 scraped and added to the file.
# Chapter 144 scraped and added to the file.
# Chapter 145 scraped and added to the file.
# Chapter 146 scraped and added to the file.
# Chapter 147 scraped and added to the file.
# Chapter 148 scraped and added to the file.
# Chapter 149 scraped and added to the file.
# Chapter 150 scraped and added to the file.
# Chapter 151 scraped and added to the file.
# Chapter 152 scraped and added to the file.
# Chapter 153 scraped and added to the file.
# Chapter 154 scraped and added to the file.
# Chapter 155 scraped and added to the file.
# Chapter 156 scraped and added to the file.
# Chapter 157 scraped and added to the file.
# Chapter 158 scraped and added to the file.
# Chapter 159 scraped and added to the file.
# Chapter 160 scraped and added to the file.
# Chapter 161 scraped and added to the file.
# Chapter 162 scraped and added to the file.
# Chapter 163 scraped and added to the file.
# Chapter 164 scraped and added to the file.
# Chapter 165 scraped and added to the file.
# Chapter 166 scraped and added to the file.
# Chapter 167 scraped and added to the file.
# Chapter 168 scraped and added to the file.
# Chapter 169 scraped and added to the file.
# Chapter 170 scraped and added to the file.
# Chapter 171 scraped and added to the file.
# Chapter 172 scraped and added to the file.
# Chapter 173 scraped and added to the file.
# Chapter 174 scraped and added to the file.
# Chapter 175 scraped and added to the file.
# Chapter 176 scraped and added to the file.
# Chapter 177 scraped and added to the file.
# Chapter 178 scraped and added to the file.
# Chapter 179 scraped and added to the file.
# Chapter 180 scraped and added to the file.
# Chapter 181 scraped and added to the file.
# Chapter 182 scraped and added to the file.
# Chapter 183 scraped and added to the file.
# Chapter 184 scraped and added to the file.
# Chapter 185 scraped and added to the file.
# Chapter 186 scraped and added to the file.
# Chapter 187 scraped and added to the file.
# Chapter 188 scraped and added to the file.
# Chapter 189 scraped and added to the file.
# Chapter 190 scraped and added to the file.
# Chapter 191 scraped and added to the file.
# Chapter 192 scraped and added to the file.
# Chapter 193 scraped and added to the file.
# Chapter 194 scraped and added to the file.
# Chapter 195 scraped and added to the file.
# Chapter 196 scraped and added to the file.
# Chapter 197 scraped and added to the file.
# Chapter 198 scraped and added to the file.
# Chapter 199 scraped and added to the file.
# Chapter 200 scraped and added to the file.
# Chapter 201 scraped and added to the file.
# Chapter 202 scraped and added to the file.
# Chapter 203 scraped and added to the file.
# Chapter 204 scraped and added to the file.
# Chapter 205 scraped and added to the file.
# Chapter 206 scraped and added to the file.
# Chapter 207 scraped and added to the file.
# Chapter 208 scraped and added to the file.
# Chapter 209 scraped and added to the file.
# Chapter 210 scraped and added to the file.
# Chapter 211 scraped and added to the file.
# Chapter 212 scraped and added to the file.
# Chapter 213 scraped and added to the file.
# Chapter 214 scraped and added to the file.
# Chapter 215 scraped and added to the file.
# Chapter 216 scraped and added to the file.
# Chapter 217 scraped and added to the file.
# Chapter 218 scraped and added to the file.
# Chapter 219 scraped and added to the file.
# Chapter 220 scraped and added to the file.
# Chapter 221 scraped and added to the file.
# Chapter 222 scraped and added to the file.
# Chapter 223 scraped and added to the file.
# Chapter 224 scraped and added to the file.
# Chapter 225 scraped and added to the file.
# Chapter 226 scraped and added to the file.
# Chapter 227 scraped and added to the file.
# Chapter 228 scraped and added to the file.
# Chapter 229 scraped and added to the file.
# Chapter 230 scraped and added to the file.
# Chapter 231 scraped and added to the file.
# Chapter 232 scraped and added to the file.
# Chapter 233 scraped and added to the file.
# Chapter 234 scraped and added to the file.
# Chapter 235 scraped and added to the file.
# Chapter 236 scraped and added to the file.
# Chapter 237 scraped and added to the file.
# Chapter 238 scraped and added to the file.
# Chapter 239 scraped and added to the file.
# Chapter 240 scraped and added to the file.
# Chapter 241 scraped and added to the file.
# Chapter 242 scraped and added to the file.
# Chapter 243 scraped and added to the file.
# Chapter 244 scraped and added to the file.
# Chapter 245 scraped and added to the file.
# Chapter 246 scraped and added to the file.
# Chapter 247 scraped and added to the file.
# Chapter 248 scraped and added to the file.
# Chapter 249 scraped and added to the file.
# Chapter 250 scraped and added to the file.
# Chapter 251 scraped and added to the file.
# Chapter 252 scraped and added to the file.
# Chapter 253 scraped and added to the file.
# Chapter 254 scraped and added to the file.
# Chapter 255 scraped and added to the file.
# Chapter 256 scraped and added to the file.
# Chapter 257 scraped and added to the file.
# Chapter 258 scraped and added to the file.
# Chapter 259 scraped and added to the file.
# Chapter 260 scraped and added to the file.
# Chapter 261 scraped and added to the file.
# Chapter 262 scraped and added to the file.
# Chapter 263 scraped and added to the file.
# Chapter 264 scraped and added to the file.
# Chapter 265 scraped and added to the file.
# Chapter 266 scraped and added to the file.
# Chapter 267 scraped and added to the file.
# Chapter 268 scraped and added to the file.
# Chapter 269 scraped and added to the file.
# Chapter 270 scraped and added to the file.
# Chapter 271 scraped and added to the file.
# Chapter 272 scraped and added to the file.
# Chapter 273 scraped and added to the file.
# Chapter 274 scraped and added to the file.
# Chapter 275 scraped and added to the file.
# Chapter 276 scraped and added to the file.
# Chapter 277 scraped and added to the file.
# Chapter 278 scraped and added to the file.
# Chapter 279 scraped and added to the file.
# Chapter 280 scraped and added to the file.
# Chapter 281 scraped and added to the file.
# Chapter 282 scraped and added to the file.
# Chapter 283 scraped and added to the file.
# Chapter 284 scraped and added to the file.
# Chapter 285 scraped and added to the file.
# Chapter 286 scraped and added to the file.
# Chapter 287 scraped and added to the file.
# Chapter 288 scraped and added to the file.
# Chapter 289 scraped and added to the file.
# Chapter 290 scraped and added to the file.
# Chapter 291 scraped and added to the file.
# Chapter 292 scraped and added to the file.
# Chapter 293 scraped and added to the file.
# Chapter 294 scraped and added to the file.
# Chapter 295 scraped and added to the file.
# Chapter 296 scraped and added to the file.
# Chapter 297 scraped and added to the file.
# Chapter 298 scraped and added to the file.
# Chapter 299 scraped and added to the file.
# Chapter 300 scraped and added to the file.
# Chapter 301 scraped and added to the file.
# Chapter 302 scraped and added to the file.
# Chapter 303 scraped and added to the file.
# Chapter 304 scraped and added to the file.
# Chapter 305 scraped and added to the file.
# Chapter 306 scraped and added to the file.
# Chapter 307 scraped and added to the file.
# Chapter 308 scraped and added to the file.
# Chapter 309 scraped and added to the file.
# Chapter 310 scraped and added to the file.
# Chapter 311 scraped and added to the file.
# Chapter 312 scraped and added to the file.
# Chapter 313 scraped and added to the file.
# Chapter 314 scraped and added to the file.
# Chapter 315 scraped and added to the file.
# Chapter 316 scraped and added to the file.
# Chapter 317 scraped and added to the file.
# Chapter 318 scraped and added to the file.
# Chapter 319 scraped and added to the file.
# Chapter 320 scraped and added to the file.
# Chapter 321 scraped and added to the file.
# Chapter 322 scraped and added to the file.
# Chapter 323 scraped and added to the file.
# Chapter 324 scraped and added to the file.
# Chapter 325 scraped and added to the file.
# Chapter 326 scraped and added to the file.
# Chapter 327 scraped and added to the file.
# Chapter 328 scraped and added to the file.
# Chapter 329 scraped and added to the file.
# Chapter 330 scraped and added to the file.
# Chapter 331 scraped and added to the file.
# Chapter 332 scraped and added to the file.
# Chapter 333 scraped and added to the file.
# Chapter 334 scraped and added to the file.
# Chapter 335 scraped and added to the file.
# Chapter 336 scraped and added to the file.
# Chapter 337 scraped and added to the file.
# Chapter 338 scraped and added to the file.
# Chapter 339 scraped and added to the file.
# Chapter 340 scraped and added to the file.
# Chapter 341 scraped and added to the file.
# Chapter 342 scraped and added to the file.
# Chapter 343 scraped and added to the file.
# Chapter 344 scraped and added to the file.
# Chapter 345 scraped and added to the file.
# Chapter 346 scraped and added to the file.
# Chapter 347 scraped and added to the file.
# Chapter 348 scraped and added to the file.
# Chapter 349 scraped and added to the file.
# Chapter 350 scraped and added to the file.
# Chapter 351 scraped and added to the file.
# Chapter 352 scraped and added to the file.
# All 352 chapters have been scraped and saved to Sorcerers_Handbook_All_Chapters.txt.

# %%
import requests
from bs4 import BeautifulSoup
from ebooklib import epub

def scrape_chapter(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Extracting the chapter title
    title_tag = soup.find('h1')
    if title_tag:
        title = title_tag.text.strip()
    else:
        title = "No Title Found"

    # Extracting the main content of the chapter
    content_div = soup.find('div', class_='entry-content')  # Use the correct class or ID for the main content
    if content_div:
        paragraphs = content_div.find_all('p')
        chapter_text = '\n'.join(p.text.strip() for p in paragraphs)
    else:
        chapter_text = "No Content Found"

    # Return the extracted title and chapter content
    return title, chapter_text

# Create a new EPUB book
book = epub.EpubBook()

# Set metadata
book.set_identifier('id123456')
book.set_title('Sorcerer’s Handbook')
book.set_language('en')

# Add author
book.add_author('Author Name')  # You can replace this with the actual author's name

# Loop through all chapter URLs and add them to the EPUB
base_url = 'https://hoxionia.com/sorcerers-handbook-chapter-'
total_chapters = 352

for i in range(1, total_chapters + 1):
    chapter_url = f"{base_url}{i}/"
    title, chapter_text = scrape_chapter(chapter_url)

    # Create an EPUB chapter
    chapter = epub.EpubHtml(title=title, file_name=f'chap_{i}.xhtml', lang='en')
    chapter.content = f'<h1>{title}</h1><p>{chapter_text.replace("\n", "</p><p>")}</p>'

    # Add chapter to the book
    book.add_item(chapter)
    book.toc.append(chapter)
    book.spine.append(chapter)

    print(f"Chapter {i} scraped and added to the EPUB.")

# Define Table of Contents and Spine
book.toc = tuple(book.toc)

# Add navigation files
book.add_item(epub.EpubNcx())
book.add_item(epub.EpubNav())

# Write the EPUB file
epub.write_epub('Sorcerers_Handbook.epub', book, {})

print(f"All {total_chapters} chapters have been scraped and saved to 'Sorcerers_Handbook.epub'.")
# Out:
# Chapter 1 scraped and added to the EPUB.
# Chapter 2 scraped and added to the EPUB.
# Chapter 3 scraped and added to the EPUB.
# Chapter 4 scraped and added to the EPUB.
# Chapter 5 scraped and added to the EPUB.
# Chapter 6 scraped and added to the EPUB.
# Chapter 7 scraped and added to the EPUB.
# Chapter 8 scraped and added to the EPUB.
# Chapter 9 scraped and added to the EPUB.
# Chapter 10 scraped and added to the EPUB.
# Chapter 11 scraped and added to the EPUB.
# Chapter 12 scraped and added to the EPUB.
# Chapter 13 scraped and added to the EPUB.
# Chapter 14 scraped and added to the EPUB.
# Chapter 15 scraped and added to the EPUB.
# Chapter 16 scraped and added to the EPUB.
# Chapter 17 scraped and added to the EPUB.
# Chapter 18 scraped and added to the EPUB.
# Chapter 19 scraped and added to the EPUB.
# Chapter 20 scraped and added to the EPUB.
# Chapter 21 scraped and added to the EPUB.
# Chapter 22 scraped and added to the EPUB.
# Chapter 23 scraped and added to the EPUB.
# Chapter 24 scraped and added to the EPUB.
# Chapter 25 scraped and added to the EPUB.
# Chapter 26 scraped and added to the EPUB.
# Chapter 27 scraped and added to the EPUB.
# Chapter 28 scraped and added to the EPUB.
# Chapter 29 scraped and added to the EPUB.
# Chapter 30 scraped and added to the EPUB.
# Chapter 31 scraped and added to the EPUB.
# Chapter 32 scraped and added to the EPUB.
# Chapter 33 scraped and added to the EPUB.
# Chapter 34 scraped and added to the EPUB.
# Chapter 35 scraped and added to the EPUB.
# Chapter 36 scraped and added to the EPUB.
# Chapter 37 scraped and added to the EPUB.
# Chapter 38 scraped and added to the EPUB.
# Chapter 39 scraped and added to the EPUB.
# Chapter 40 scraped and added to the EPUB.
# Chapter 41 scraped and added to the EPUB.
# Chapter 42 scraped and added to the EPUB.
# Chapter 43 scraped and added to the EPUB.
# Chapter 44 scraped and added to the EPUB.
# Chapter 45 scraped and added to the EPUB.
# Chapter 46 scraped and added to the EPUB.
# Chapter 47 scraped and added to the EPUB.
# Chapter 48 scraped and added to the EPUB.
# Chapter 49 scraped and added to the EPUB.
# Chapter 50 scraped and added to the EPUB.
# Chapter 51 scraped and added to the EPUB.
# Chapter 52 scraped and added to the EPUB.
# Chapter 53 scraped and added to the EPUB.
# Chapter 54 scraped and added to the EPUB.
# Chapter 55 scraped and added to the EPUB.
# Chapter 56 scraped and added to the EPUB.
# Chapter 57 scraped and added to the EPUB.
# Chapter 58 scraped and added to the EPUB.
# Chapter 59 scraped and added to the EPUB.
# Chapter 60 scraped and added to the EPUB.
# Chapter 61 scraped and added to the EPUB.
# Chapter 62 scraped and added to the EPUB.
# Chapter 63 scraped and added to the EPUB.
# Chapter 64 scraped and added to the EPUB.
# Chapter 65 scraped and added to the EPUB.
# Chapter 66 scraped and added to the EPUB.
# Chapter 67 scraped and added to the EPUB.
# Chapter 68 scraped and added to the EPUB.
# Chapter 69 scraped and added to the EPUB.
# Chapter 70 scraped and added to the EPUB.
# Chapter 71 scraped and added to the EPUB.
# Chapter 72 scraped and added to the EPUB.
# Chapter 73 scraped and added to the EPUB.
# Chapter 74 scraped and added to the EPUB.
# Chapter 75 scraped and added to the EPUB.
# Chapter 76 scraped and added to the EPUB.
# Chapter 77 scraped and added to the EPUB.
# Chapter 78 scraped and added to the EPUB.
# Chapter 79 scraped and added to the EPUB.
# Chapter 80 scraped and added to the EPUB.
# Chapter 81 scraped and added to the EPUB.
# Chapter 82 scraped and added to the EPUB.
# Chapter 83 scraped and added to the EPUB.
# Chapter 84 scraped and added to the EPUB.
# Chapter 85 scraped and added to the EPUB.
# Chapter 86 scraped and added to the EPUB.
# Chapter 87 scraped and added to the EPUB.
# Chapter 88 scraped and added to the EPUB.
# Chapter 89 scraped and added to the EPUB.
# Chapter 90 scraped and added to the EPUB.
# Chapter 91 scraped and added to the EPUB.
# Chapter 92 scraped and added to the EPUB.
# Chapter 93 scraped and added to the EPUB.
# Chapter 94 scraped and added to the EPUB.
# Chapter 95 scraped and added to the EPUB.
# Chapter 96 scraped and added to the EPUB.
# Chapter 97 scraped and added to the EPUB.
# Chapter 98 scraped and added to the EPUB.
# Chapter 99 scraped and added to the EPUB.
# Chapter 100 scraped and added to the EPUB.
# Chapter 101 scraped and added to the EPUB.
# Chapter 102 scraped and added to the EPUB.
# Chapter 103 scraped and added to the EPUB.
# Chapter 104 scraped and added to the EPUB.
# Chapter 105 scraped and added to the EPUB.
# Chapter 106 scraped and added to the EPUB.
# Chapter 107 scraped and added to the EPUB.
# Chapter 108 scraped and added to the EPUB.
# Chapter 109 scraped and added to the EPUB.
# Chapter 110 scraped and added to the EPUB.
# Chapter 111 scraped and added to the EPUB.
# Chapter 112 scraped and added to the EPUB.
# Chapter 113 scraped and added to the EPUB.
# Chapter 114 scraped and added to the EPUB.
# Chapter 115 scraped and added to the EPUB.
# Chapter 116 scraped and added to the EPUB.
# Chapter 117 scraped and added to the EPUB.
# Chapter 118 scraped and added to the EPUB.
# Chapter 119 scraped and added to the EPUB.
# Chapter 120 scraped and added to the EPUB.
# Chapter 121 scraped and added to the EPUB.
# Chapter 122 scraped and added to the EPUB.
# Chapter 123 scraped and added to the EPUB.
# Chapter 124 scraped and added to the EPUB.
# Chapter 125 scraped and added to the EPUB.
# Chapter 126 scraped and added to the EPUB.
# Chapter 127 scraped and added to the EPUB.
# Chapter 128 scraped and added to the EPUB.
# Chapter 129 scraped and added to the EPUB.
# Chapter 130 scraped and added to the EPUB.
# Chapter 131 scraped and added to the EPUB.
# Chapter 132 scraped and added to the EPUB.
# Chapter 133 scraped and added to the EPUB.
# Chapter 134 scraped and added to the EPUB.
# Chapter 135 scraped and added to the EPUB.
# Chapter 136 scraped and added to the EPUB.
# Chapter 137 scraped and added to the EPUB.
# Chapter 138 scraped and added to the EPUB.
# Chapter 139 scraped and added to the EPUB.
# Chapter 140 scraped and added to the EPUB.
# Chapter 141 scraped and added to the EPUB.
# Chapter 142 scraped and added to the EPUB.
# Chapter 143 scraped and added to the EPUB.
# Chapter 144 scraped and added to the EPUB.
# Chapter 145 scraped and added to the EPUB.
# Chapter 146 scraped and added to the EPUB.
# Chapter 147 scraped and added to the EPUB.
# Chapter 148 scraped and added to the EPUB.
# Chapter 149 scraped and added to the EPUB.
# Chapter 150 scraped and added to the EPUB.
# Chapter 151 scraped and added to the EPUB.
# Chapter 152 scraped and added to the EPUB.
# Chapter 153 scraped and added to the EPUB.
# Chapter 154 scraped and added to the EPUB.
# Chapter 155 scraped and added to the EPUB.
# Chapter 156 scraped and added to the EPUB.
# Chapter 157 scraped and added to the EPUB.
# Chapter 158 scraped and added to the EPUB.
# Chapter 159 scraped and added to the EPUB.
# Chapter 160 scraped and added to the EPUB.
# Chapter 161 scraped and added to the EPUB.
# Chapter 162 scraped and added to the EPUB.
# Chapter 163 scraped and added to the EPUB.
# Chapter 164 scraped and added to the EPUB.
# Chapter 165 scraped and added to the EPUB.
# Chapter 166 scraped and added to the EPUB.
# Chapter 167 scraped and added to the EPUB.
# Chapter 168 scraped and added to the EPUB.
# Chapter 169 scraped and added to the EPUB.
# Chapter 170 scraped and added to the EPUB.
# Chapter 171 scraped and added to the EPUB.
# Chapter 172 scraped and added to the EPUB.
# Chapter 173 scraped and added to the EPUB.
# Chapter 174 scraped and added to the EPUB.
# Chapter 175 scraped and added to the EPUB.
# Chapter 176 scraped and added to the EPUB.
# Chapter 177 scraped and added to the EPUB.
# Chapter 178 scraped and added to the EPUB.
# Chapter 179 scraped and added to the EPUB.
# Chapter 180 scraped and added to the EPUB.
# Chapter 181 scraped and added to the EPUB.
# Chapter 182 scraped and added to the EPUB.
# Chapter 183 scraped and added to the EPUB.
# Chapter 184 scraped and added to the EPUB.
# Chapter 185 scraped and added to the EPUB.
# Chapter 186 scraped and added to the EPUB.
# Chapter 187 scraped and added to the EPUB.
# Chapter 188 scraped and added to the EPUB.
# Chapter 189 scraped and added to the EPUB.
# Chapter 190 scraped and added to the EPUB.
# Chapter 191 scraped and added to the EPUB.
# Chapter 192 scraped and added to the EPUB.
# Chapter 193 scraped and added to the EPUB.
# Chapter 194 scraped and added to the EPUB.
# Chapter 195 scraped and added to the EPUB.
# Chapter 196 scraped and added to the EPUB.
# Chapter 197 scraped and added to the EPUB.
# Chapter 198 scraped and added to the EPUB.
# Chapter 199 scraped and added to the EPUB.
# Chapter 200 scraped and added to the EPUB.
# Chapter 201 scraped and added to the EPUB.
# Chapter 202 scraped and added to the EPUB.
# Chapter 203 scraped and added to the EPUB.
# Chapter 204 scraped and added to the EPUB.
# Chapter 205 scraped and added to the EPUB.
# Chapter 206 scraped and added to the EPUB.
# Chapter 207 scraped and added to the EPUB.
# Chapter 208 scraped and added to the EPUB.
# Chapter 209 scraped and added to the EPUB.
# Chapter 210 scraped and added to the EPUB.
# Chapter 211 scraped and added to the EPUB.
# Chapter 212 scraped and added to the EPUB.
# Chapter 213 scraped and added to the EPUB.
# Chapter 214 scraped and added to the EPUB.
# Chapter 215 scraped and added to the EPUB.
# Chapter 216 scraped and added to the EPUB.
# Chapter 217 scraped and added to the EPUB.
# Chapter 218 scraped and added to the EPUB.
# Chapter 219 scraped and added to the EPUB.
# Chapter 220 scraped and added to the EPUB.
# Chapter 221 scraped and added to the EPUB.
# Chapter 222 scraped and added to the EPUB.
# Chapter 223 scraped and added to the EPUB.
# Chapter 224 scraped and added to the EPUB.
# Chapter 225 scraped and added to the EPUB.
# Chapter 226 scraped and added to the EPUB.
# Chapter 227 scraped and added to the EPUB.
# Chapter 228 scraped and added to the EPUB.
# Chapter 229 scraped and added to the EPUB.
# Chapter 230 scraped and added to the EPUB.
# Chapter 231 scraped and added to the EPUB.
# Chapter 232 scraped and added to the EPUB.
# Chapter 233 scraped and added to the EPUB.
# Chapter 234 scraped and added to the EPUB.
# Chapter 235 scraped and added to the EPUB.
# Chapter 236 scraped and added to the EPUB.
# Chapter 237 scraped and added to the EPUB.
# Chapter 238 scraped and added to the EPUB.
# Chapter 239 scraped and added to the EPUB.
# Chapter 240 scraped and added to the EPUB.
# Chapter 241 scraped and added to the EPUB.
# Chapter 242 scraped and added to the EPUB.
# Chapter 243 scraped and added to the EPUB.
# Chapter 244 scraped and added to the EPUB.
# Chapter 245 scraped and added to the EPUB.
# Chapter 246 scraped and added to the EPUB.
# Chapter 247 scraped and added to the EPUB.
# Chapter 248 scraped and added to the EPUB.
# Chapter 249 scraped and added to the EPUB.
# Chapter 250 scraped and added to the EPUB.
# Chapter 251 scraped and added to the EPUB.
# Chapter 252 scraped and added to the EPUB.
# Chapter 253 scraped and added to the EPUB.
# Chapter 254 scraped and added to the EPUB.
# Chapter 255 scraped and added to the EPUB.
# Chapter 256 scraped and added to the EPUB.
# Chapter 257 scraped and added to the EPUB.
# Chapter 258 scraped and added to the EPUB.
# Chapter 259 scraped and added to the EPUB.
# Chapter 260 scraped and added to the EPUB.
# Chapter 261 scraped and added to the EPUB.
# Chapter 262 scraped and added to the EPUB.
# Chapter 263 scraped and added to the EPUB.
# Chapter 264 scraped and added to the EPUB.
# Chapter 265 scraped and added to the EPUB.
# Chapter 266 scraped and added to the EPUB.
# Chapter 267 scraped and added to the EPUB.
# Chapter 268 scraped and added to the EPUB.
# Chapter 269 scraped and added to the EPUB.
# Chapter 270 scraped and added to the EPUB.
# Chapter 271 scraped and added to the EPUB.
# Chapter 272 scraped and added to the EPUB.
# Chapter 273 scraped and added to the EPUB.
# Chapter 274 scraped and added to the EPUB.
# Chapter 275 scraped and added to the EPUB.
# Chapter 276 scraped and added to the EPUB.
# Chapter 277 scraped and added to the EPUB.
# Chapter 278 scraped and added to the EPUB.
# Chapter 279 scraped and added to the EPUB.
# Chapter 280 scraped and added to the EPUB.
# Chapter 281 scraped and added to the EPUB.
# Chapter 282 scraped and added to the EPUB.
# Chapter 283 scraped and added to the EPUB.
# Chapter 284 scraped and added to the EPUB.
# Chapter 285 scraped and added to the EPUB.
# Chapter 286 scraped and added to the EPUB.
# Chapter 287 scraped and added to the EPUB.
# Chapter 288 scraped and added to the EPUB.
# Chapter 289 scraped and added to the EPUB.
# Chapter 290 scraped and added to the EPUB.
# Chapter 291 scraped and added to the EPUB.
# Chapter 292 scraped and added to the EPUB.
# Chapter 293 scraped and added to the EPUB.
# Chapter 294 scraped and added to the EPUB.
# Chapter 295 scraped and added to the EPUB.
# Chapter 296 scraped and added to the EPUB.
# Chapter 297 scraped and added to the EPUB.
# Chapter 298 scraped and added to the EPUB.
# Chapter 299 scraped and added to the EPUB.
# Chapter 300 scraped and added to the EPUB.
# Chapter 301 scraped and added to the EPUB.
# Chapter 302 scraped and added to the EPUB.
# Chapter 303 scraped and added to the EPUB.
# Chapter 304 scraped and added to the EPUB.
# Chapter 305 scraped and added to the EPUB.
# Chapter 306 scraped and added to the EPUB.
# Chapter 307 scraped and added to the EPUB.
# Chapter 308 scraped and added to the EPUB.
# Chapter 309 scraped and added to the EPUB.
# Chapter 310 scraped and added to the EPUB.
# Chapter 311 scraped and added to the EPUB.
# Chapter 312 scraped and added to the EPUB.
# Chapter 313 scraped and added to the EPUB.
# Chapter 314 scraped and added to the EPUB.
# Chapter 315 scraped and added to the EPUB.
# Chapter 316 scraped and added to the EPUB.
# Chapter 317 scraped and added to the EPUB.
# Chapter 318 scraped and added to the EPUB.
# Chapter 319 scraped and added to the EPUB.
# Chapter 320 scraped and added to the EPUB.
# Chapter 321 scraped and added to the EPUB.
# Chapter 322 scraped and added to the EPUB.
# Chapter 323 scraped and added to the EPUB.
# Chapter 324 scraped and added to the EPUB.
# Chapter 325 scraped and added to the EPUB.
# Chapter 326 scraped and added to the EPUB.
# Chapter 327 scraped and added to the EPUB.
# Chapter 328 scraped and added to the EPUB.
# Chapter 329 scraped and added to the EPUB.
# Chapter 330 scraped and added to the EPUB.
# Chapter 331 scraped and added to the EPUB.
# Chapter 332 scraped and added to the EPUB.
# Chapter 333 scraped and added to the EPUB.
# Chapter 334 scraped and added to the EPUB.
# Chapter 335 scraped and added to the EPUB.
# Chapter 336 scraped and added to the EPUB.
# Chapter 337 scraped and added to the EPUB.
# Chapter 338 scraped and added to the EPUB.
# Chapter 339 scraped and added to the EPUB.
# Chapter 340 scraped and added to the EPUB.
# Chapter 341 scraped and added to the EPUB.
# Chapter 342 scraped and added to the EPUB.
# Chapter 343 scraped and added to the EPUB.
# Chapter 344 scraped and added to the EPUB.
# Chapter 345 scraped and added to the EPUB.
# Chapter 346 scraped and added to the EPUB.
# Chapter 347 scraped and added to the EPUB.
# Chapter 348 scraped and added to the EPUB.
# Chapter 349 scraped and added to the EPUB.
# Chapter 350 scraped and added to the EPUB.
# Chapter 351 scraped and added to the EPUB.
# Chapter 352 scraped and added to the EPUB.
# All 352 chapters have been scraped and saved to 'Sorcerers_Handbook.epub'.
